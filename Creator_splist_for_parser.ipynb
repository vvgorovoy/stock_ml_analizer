# %% [markdown]
# # Программа для создания списка для парсера финансовых данных

# %% [markdown]
# Загружаем необходимые библиотеки

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Загружаем список компаний с тикерами, секторами и подсекторами

# %%
splist = pd.read_csv(r"Data/splist.csv")

# %%
splist
# Out:
#                         Company Ticker                  Sector  \
# 0                    Apple Inc.   AAPL  Information Technology
# 1         Microsoft Corporation   MSFT  Information Technology
# 2               Amazon.com Inc.   AMZN  Consumer Discretionary
# 3                     Tesla Inc   TSLA  Consumer Discretionary
# 4         Facebook Inc. Class A     FB  Communication Services
# ..                          ...    ...                     ...
# 493                Vontier Corp    VNT  Information Technology
# 494   HollyFrontier Corporation    HFC                  Energy
# 495                    Gap Inc.    GPS  Consumer Discretionary
# 496  Xerox Holdings Corporation    XRX  Information Technology
# 497   Under Armour Inc. Class A    UAA  Consumer Discretionary
#
#                                      Sub-sector
# 0    Technology Hardware, Storage & Peripherals
# 1                              Systems Software
# 2            Internet & Direct Marketing Retail
# 3                      Automobile Manufacturers
# 4                  Interactive Media & Services
# ..                                          ...
# 493          Electronic Equipment & Instruments
# 494              Oil & Gas Refining & Marketing
# 495                              Apparel Retail
# 496  Technology Hardware, Storage & Peripherals
# 497         Apparel, Accessories & Luxury Goods
#
# [498 rows x 4 columns]

# %% [markdown]
# Проверяем на наличие необычных явлений

# %%
splist.Company.value_counts()
# Out:
# Tyler Technologies Inc.               1
# Incyte Corporation                    1
# Huntington Ingalls Industries Inc.    1
# KLA Corporation                       1
# Crown Castle International Corp       1
#                                      ..
# Otis Worldwide Corporation            1
# Principal Financial Group Inc.        1
# PVH Corp.                             1
# Micron Technology Inc.                1
# Walgreens Boots Alliance Inc          1
# Name: Company, Length: 498, dtype: int64

# %%
splist.Ticker.value_counts()
# Out:
# AAL     1
# LLY     1
# BXP     1
# VRSK    1
# XYL     1
#        ..
# EXR     1
# AVGO    1
# DG      1
# STZ     1
# COO     1
# Name: Ticker, Length: 498, dtype: int64

# %% [markdown]
# Получаем список всех компаний и затем преобразуем его специально под формат ссылок на сайт

# %%
full_companies = splist.Company.tolist()
full_companies
# Out:
# ['Apple Inc.',
#  'Microsoft Corporation',
#  'Amazon.com Inc.',
#  'Tesla Inc',
#  'Facebook Inc. Class A',
#  'Alphabet Inc. Class A',
#  'Berkshire Hathaway Inc. Class B',
#  'Johnson & Johnson',
#  'JPMorgan Chase & Co.',
#  'Visa Inc. Class A',
#  'NVIDIA Corporation',
#  'Procter & Gamble Company',
#  'UnitedHealth Group Incorporated',
#  'Walt Disney Company',
#  'Home Depot Inc.',
#  'PayPal Holdings Inc',
#  'Mastercard Incorporated Class A',
#  'Netflix Inc.',
#  'Intel Corporation',
#  'Comcast Corporation Class A',
#  'Bank of America Corp',
#  'Adobe Inc.',
#  'Verizon Communications Inc.',
#  'Abbott Laboratories',
#  'salesforce.com inc.',
#  'Thermo Fisher Scientific Inc.',
#  'AT&T Inc.',
#  'Pfizer Inc.',
#  'Merck & Co. Inc.',
#  'Walmart Inc.',
#  'Cisco Systems Inc.',
#  'Exxon Mobil Corporation',
#  'PepsiCo Inc.',
#  'Broadcom Inc.',
#  'Coca-Cola Company',
#  'Qualcomm Inc',
#  'AbbVie Inc.',
#  'NIKE Inc. Class B',
#  'Chevron Corporation',
#  'Eli Lilly and Company',
#  'NextEra Energy Inc.',
#  'Texas Instruments Incorporated',
#  'Accenture Plc Class A',
#  "McDonald's Corporation",
#  'Costco Wholesale Corporation',
#  'Danaher Corporation',
#  'Medtronic Plc',
#  'Bristol-Myers Squibb Company',
#  'Amgen Inc.',
#  'Honeywell International Inc.',
#  'Union Pacific Corporation',
#  'Linde plc',
#  'Wells Fargo & Company',
#  'Philip Morris International Inc.',
#  'Citigroup Inc.',
#  "Lowe's Companies Inc.",
#  'Oracle Corporation',
#  'Starbucks Corporation',
#  'United Parcel Service Inc. Class B',
#  'ServiceNow Inc.',
#  'International Business Machines Corporation',
#  'Advanced Micro Devices Inc.',
#  'American Tower Corporation',
#  'Boeing Company',
#  'Raytheon Technologies Corporation',
#  'BlackRock Inc.',
#  '3M Company',
#  'Caterpillar Inc.',
#  'Intuit Inc.',
#  'Morgan Stanley',
#  'Goldman Sachs Group Inc.',
#  'General Electric Company',
#  'CVS Health Corporation',
#  'Applied Materials Inc.',
#  'Target Corporation',
#  'Deere & Company',
#  'Micron Technology Inc.',
#  'Intuitive Surgical Inc.',
#  'Charter Communications Inc. Class A',
#  'Gilead Sciences Inc.',
#  'Booking Holdings Inc.',
#  'Fidelity National Information Services Inc.',
#  'Lockheed Martin Corporation',
#  'Charles Schwab Corporation',
#  'Mondelez International Inc. Class A',
#  'Cigna Corporation',
#  'Prologis Inc.',
#  'S&P Global Inc.',
#  'TJX Companies Inc',
#  'American Express Company',
#  'Becton Dickinson and Company',
#  'Altria Group Inc',
#  'T-Mobile US Inc.',
#  'Stryker Corporation',
#  'Zoetis Inc. Class A',
#  'Anthem Inc.',
#  'Lam Research Corporation',
#  'Automatic Data Processing Inc.',
#  'Crown Castle International Corp',
#  'Activision Blizzard Inc.',
#  'Duke Energy Corporation',
#  'Equinix Inc.',
#  'Colgate-Palmolive Company',
#  'CME Group Inc. Class A',
#  'Chubb Limited',
#  'CSX Corporation',
#  'Truist Financial Corporation',
#  'General Motors Company',
#  'Illumina Inc.',
#  'Intercontinental Exchange Inc.',
#  'Autodesk Inc.',
#  'Southern Company',
#  'PNC Financial Services Group Inc.',
#  'Fiserv Inc.',
#  'Norfolk Southern Corporation',
#  'Vertex Pharmaceuticals Incorporated',
#  'Air Products and Chemicals Inc.',
#  'Dominion Energy Inc',
#  'U.S. Bancorp',
#  'FedEx Corporation',
#  'Sherwin-Williams Company',
#  'Illinois Tool Works Inc.',
#  'Analog Devices Inc.',
#  'Marsh & McLennan Companies Inc.',
#  'ConocoPhillips',
#  'Estee Lauder Companies Inc. Class A',
#  'Global Payments Inc.',
#  'DuPont de Nemours Inc.',
#  'Regeneron Pharmaceuticals Inc.',
#  'Ecolab Inc.',
#  'Boston Scientific Corporation',
#  'Edwards Lifesciences Corporation',
#  'Progressive Corporation',
#  'Humana Inc.',
#  'Eaton Corp. Plc',
#  'Emerson Electric Co.',
#  'Newmont Corporation',
#  'Aon Plc Class A',
#  'Dollar General Corporation',
#  'Capital One Financial Corporation',
#  'Northrop Grumman Corporation',
#  'Kimberly-Clark Corporation',
#  'KLA Corporation',
#  'HCA Healthcare Inc',
#  "Moody's Corporation",
#  'Waste Management Inc.',
#  'Biogen Inc.',
#  'Ford Motor Company',
#  'Electronic Arts Inc.',
#  'Chipotle Mexican Grill Inc.',
#  'Cognizant Technology Solutions Corporation Class A',
#  'IDEXX Laboratories Inc.',
#  'Twitter Inc.',
#  'Digital Realty Trust Inc.',
#  'TE Connectivity Ltd.',
#  'Exelon Corporation',
#  'Roper Technologies Inc.',
#  'Freeport-McMoRan Inc.',
#  'American Electric Power Company Inc.',
#  'Synopsys Inc.',
#  'Ross Stores Inc.',
#  'Dow Inc.',
#  'Baxter International Inc.',
#  'Align Technology Inc.',
#  'eBay Inc.',
#  'Amphenol Corporation Class A',
#  'Cadence Design Systems Inc.',
#  'Aptiv PLC',
#  'MetLife Inc.',
#  'Microchip Technology Incorporated',
#  'Agilent Technologies Inc.',
#  'Johnson Controls International plc',
#  'DexCom Inc.',
#  'Constellation Brands Inc. Class A',
#  'L3Harris Technologies Inc',
#  'Sysco Corporation',
#  'Sempra Energy',
#  'Public Storage',
#  'T. Rowe Price Group',
#  'General Mills Inc.',
#  'Walgreens Boots Alliance Inc',
#  'Travelers Companies Inc.',
#  'IQVIA Holdings Inc',
#  'Parker-Hannifin Corporation',
#  'Centene Corporation',
#  'MSCI Inc. Class A',
#  'Cummins Inc.',
#  'General Dynamics Corporation',
#  'Trane Technologies plc',
#  'Alexion Pharmaceuticals Inc.',
#  'HP Inc.',
#  'Xcel Energy Inc.',
#  'Xilinx Inc.',
#  'Allstate Corporation',
#  'Bank of New York Mellon Corporation',
#  'IHS Markit Ltd.',
#  'PPG Industries Inc.',
#  'Monster Beverage Corporation',
#  'American International Group Inc.',
#  'Zimmer Biomet Holdings Inc.',
#  "O'Reilly Automotive Inc.",
#  'ANSYS Inc.',
#  'PACCAR Inc',
#  'Carrier Global Corp.',
#  'Marriott International Inc. Class A',
#  'Prudential Financial Inc.',
#  'Yum! Brands Inc.',
#  'TransDigm Group Incorporated',
#  'SBA Communications Corp. Class A',
#  'Skyworks Solutions Inc.',
#  'Schlumberger NV',
#  'Simon Property Group Inc.',
#  'Corteva Inc',
#  'Verisk Analytics Inc',
#  'Eversource Energy',
#  'EOG Resources Inc.',
#  'Aflac Incorporated',
#  'Motorola Solutions Inc.',
#  'ViacomCBS Inc. Class B',
#  'Phillips 66',
#  'ResMed Inc.',
#  'American Water Works Company Inc.',
#  'Ball Corporation',
#  'Public Service Enterprise Group Inc',
#  'McKesson Corporation',
#  'Rockwell Automation Inc.',
#  'Cintas Corporation',
#  'Paychex Inc.',
#  'Hilton Worldwide Holdings Inc',
#  'Marathon Petroleum Corporation',
#  'Mettler-Toledo International Inc.',
#  'Archer-Daniels-Midland Company',
#  'WEC Energy Group Inc',
#  'Stanley Black & Decker Inc.',
#  'Corning Inc',
#  'Kinder Morgan Inc Class P',
#  'AutoZone Inc.',
#  'Willis Towers Watson Public Limited Company',
#  'Fastenal Company',
#  'Clorox Company',
#  'Keysight Technologies Inc',
#  'Southwest Airlines Co.',
#  'AMETEK Inc.',
#  'Otis Worldwide Corporation',
#  'Kroger Co.',
#  'Welltower Inc.',
#  'Williams Companies Inc.',
#  'D.R. Horton Inc.',
#  'First Republic Bank',
#  'Etsy Inc.',
#  'Discover Financial Services',
#  'V.F. Corporation',
#  'Best Buy Co. Inc.',
#  'State Street Corporation',
#  'Cerner Corporation',
#  'Pioneer Natural Resources Company',
#  'Maxim Integrated Products Inc.',
#  'Consolidated Edison Inc.',
#  'Delta Air Lines Inc.',
#  'Weyerhaeuser Company',
#  'Dollar Tree Inc.',
#  'Ameriprise Financial Inc.',
#  'SVB Financial Group',
#  'Enphase Energy Inc.',
#  'Lennar Corporation Class A',
#  'DTE Energy Company',
#  'Take-Two Interactive Software Inc.',
#  'AvalonBay Communities Inc.',
#  'Copart Inc.',
#  'Valero Energy Corporation',
#  'Laboratory Corporation of America Holdings',
#  'Fortive Corp.',
#  'LyondellBasell Industries NV',
#  'McCormick & Company Incorporated',
#  'Arthur J. Gallagher & Co.',
#  'West Pharmaceutical Services Inc.',
#  'Edison International',
#  'Equifax Inc.',
#  'MarketAxess Holdings Inc.',
#  'Kraft Heinz Company',
#  'PPL Corporation',
#  'Hershey Company',
#  'CBRE Group Inc. Class A',
#  'Equity Residential',
#  'Hologic Inc.',
#  'Zebra Technologies Corporation Class A',
#  'Realty Income Corporation',
#  'Viatris Inc.',
#  'Fifth Third Bancorp',
#  'Qorvo Inc.',
#  'Church & Dwight Co. Inc.',
#  'FLEETCOR Technologies Inc.',
#  'Alexandria Real Estate Equities Inc.',
#  'Vulcan Materials Company',
#  'Fortinet Inc.',
#  'VeriSign Inc.',
#  'CDW Corp.',
#  'International Paper Company',
#  'Teradyne Inc.',
#  'Paycom Software Inc.',
#  'Catalent Inc',
#  'Kansas City Southern',
#  'CarMax Inc.',
#  'Old Dominion Freight Line Inc.',
#  'Republic Services Inc.',
#  'Entergy Corporation',
#  'Tyson Foods Inc. Class A',
#  'Northern Trust Corporation',
#  'Synchrony Financial',
#  'Martin Marietta Materials Inc.',
#  'United Rentals Inc.',
#  'Akamai Technologies Inc.',
#  'Ameren Corporation',
#  'Quest Diagnostics Incorporated',
#  'Cooper Companies Inc.',
#  'Ventas Inc.',
#  'ONEOK Inc.',
#  'Albemarle Corporation',
#  'Teleflex Incorporated',
#  'Xylem Inc.',
#  'Western Digital Corporation',
#  'Garmin Ltd.',
#  'Hartford Financial Services Group Inc.',
#  'Expedia Group Inc.',
#  'Arista Networks Inc.',
#  'Tyler Technologies Inc.',
#  'Occidental Petroleum Corporation',
#  'Amcor PLC',
#  'Trimble Inc.',
#  'M&T Bank Corporation',
#  'PerkinElmer Inc.',
#  'Dover Corporation',
#  'Incyte Corporation',
#  'FirstEnergy Corp.',
#  'Broadridge Financial Solutions Inc.',
#  'KeyCorp',
#  'Conagra Brands Inc.',
#  'W.W. Grainger Inc.',
#  'Waters Corporation',
#  'Regions Financial Corporation',
#  'AES Corporation',
#  'CMS Energy Corporation',
#  'Healthpeak Properties Inc.',
#  'Citrix Systems Inc.',
#  'Tractor Supply Company',
#  'Las Vegas Sands Corp.',
#  'Cardinal Health Inc.',
#  'Hewlett Packard Enterprise Co.',
#  'Nasdaq Inc.',
#  'STERIS Plc',
#  'Ulta Beauty Inc',
#  'Citizens Financial Group Inc.',
#  'NVR Inc.',
#  'Ingersoll Rand Inc.',
#  'Essex Property Trust Inc.',
#  'Halliburton Company',
#  'AmerisourceBergen Corporation',
#  'Darden Restaurants Inc.',
#  'ABIOMED Inc.',
#  'Mid-America Apartment Communities Inc.',
#  'Expeditors International of Washington Inc.',
#  'Duke Realty Corporation',
#  'Extra Space Storage Inc.',
#  'Kellogg Company',
#  'Seagate Technology PLC',
#  'Hess Corporation',
#  'Nucor Corporation',
#  'NetApp Inc.',
#  "Domino's Pizza Inc.",
#  'Pool Corporation',
#  'Masco Corporation',
#  'Celanese Corporation',
#  'IDEX Corporation',
#  'FMC Corporation',
#  'Leidos Holdings Inc.',
#  'Carnival Corporation',
#  'Teledyne Technologies Incorporated',
#  'Gartner Inc.',
#  'Genuine Parts Company',
#  'Baker Hughes Company Class A',
#  'Westinghouse Air Brake Technologies Corporation',
#  'Eastman Chemical Company',
#  'Omnicom Group Inc',
#  'Huntington Bancshares Incorporated',
#  'Jacobs Engineering Group Inc.',
#  'Hormel Foods Corporation',
#  'Brown-Forman Corporation Class B',
#  'J.M. Smucker Company',
#  'Cincinnati Financial Corporation',
#  'Principal Financial Group Inc.',
#  'Boston Properties Inc.',
#  'Avery Dennison Corporation',
#  'Packaging Corporation of America',
#  'Bio-Rad Laboratories Inc. Class A',
#  'NortonLifeLock Inc.',
#  'Raymond James Financial Inc.',
#  'Fortune Brands Home & Security Inc.',
#  'Alliant Energy Corp',
#  'Evergy Inc.',
#  'Royal Caribbean Group',
#  'F5 Networks Inc.',
#  'Hasbro Inc.',
#  'PulteGroup Inc.',
#  'MGM Resorts International',
#  'DENTSPLY SIRONA Inc.',
#  'C.H. Robinson Worldwide Inc.',
#  'United Airlines Holdings Inc.',
#  'Whirlpool Corporation',
#  'Lumen Technologies Inc.',
#  'CenterPoint Energy Inc.',
#  'J.B. Hunt Transport Services Inc.',
#  'UDR Inc.',
#  'Jack Henry & Associates Inc.',
#  'Atmos Energy Corporation',
#  'Lamb Weston Holdings Inc.',
#  'WestRock Company',
#  'Fox Corporation Class A',
#  'Loews Corporation',
#  'Textron Inc.',
#  'NRG Energy Inc.',
#  'BorgWarner Inc.',
#  'American Airlines Group Inc.',
#  'Cboe Global Markets Inc',
#  'Advance Auto Parts Inc.',
#  'Allegion PLC',
#  'Quanta Services Inc.',
#  'LKQ Corporation',
#  'Snap-on Incorporated',
#  'Universal Health Services Inc. Class B',
#  'Devon Energy Corporation',
#  'Wynn Resorts Limited',
#  'L Brands Inc.',
#  'Howmet Aerospace Inc.',
#  'Campbell Soup Company',
#  'Interpublic Group of Companies Inc.',
#  'Live Nation Entertainment Inc.',
#  'Iron Mountain Inc.',
#  'Henry Schein Inc.',
#  'Host Hotels & Resorts Inc.',
#  'Molson Coors Beverage Company Class B',
#  'Western Union Company',
#  'Mosaic Company',
#  'Newell Brands Inc',
#  'CF Industries Holdings Inc.',
#  'Diamondback Energy Inc.',
#  'Pentair plc',
#  'W. R. Berkley Corporation',
#  'Tapestry Inc.',
#  'Globe Life Inc.',
#  'DaVita Inc.',
#  'Mohawk Industries Inc.',
#  'Pinnacle West Capital Corporation',
#  'NiSource Inc',
#  'Everest Re Group Ltd.',
#  'Lincoln National Corporation',
#  'IPG Photonics Corporation',
#  'Juniper Networks Inc.',
#  'Nielsen Holdings Plc',
#  'Comerica Incorporated',
#  'Invesco Ltd.',
#  'Rollins Inc.',
#  'Assurant Inc.',
#  'Robert Half International Inc.',
#  'A. O. Smith Corporation',
#  'News Corporation Class A',
#  'Cabot Oil & Gas Corporation',
#  'Regency Centers Corporation',
#  'Zions Bancorporation N.A.',
#  'DISH Network Corporation Class A',
#  'Franklin Resources Inc.',
#  'Kimco Realty Corporation',
#  'Norwegian Cruise Line Holdings Ltd.',
#  'FLIR Systems Inc.',
#  'Discovery Inc. Class A',
#  'Sealed Air Corporation',
#  'DXC Technology Co.',
#  'Huntington Ingalls Industries Inc.',
#  'Alaska Air Group Inc.',
#  'Vornado Realty Trust',
#  'Federal Realty Investment Trust',
#  'Perrigo Co. Plc',
#  'PVH Corp.',
#  "People's United Financial Inc.",
#  'Marathon Oil Corporation',
#  'Apache Corporation',
#  'Leggett & Platt Incorporated',
#  'Hanesbrands Inc.',
#  'Ralph Lauren Corporation Class A',
#  'NOV Inc.',
#  'Unum Group',
#  'SL Green Realty Corp.',
#  'Flowserve Corporation',
#  'TechnipFMC Plc',
#  'Vontier Corp',
#  'HollyFrontier Corporation',
#  'Gap Inc.',
#  'Xerox Holdings Corporation',
#  'Under Armour Inc. Class A']

# %%
companies = [company.replace("International Business Machines","IBM") for company in full_companies]
companies = [company.replace("Advanced Micro Devices","AMD") for company in companies]
companies = [company.replace("United Parcel Service","UPS") for company in companies]
companies = [company.replace("Automatic Data Processing","ADP") for company in companies]
companies = [company.replace("Altria Group","Altria") for company in companies]
companies = [company.replace("Goldman Sachs Group","Goldman Sachs") for company in companies]
companies = [company.replace("Simon Property Group","Simon Property") for company in companies]
companies = [company.replace("WEC Energy Group","WEC Energy") for company in companies]
companies = [company.replace("CBRE Group","CBRE") for company in companies]
companies = [company.replace("Citizens Financial Group","Citizens Financial") for company in companies]
companies = [company.replace("J.M. Smucker","J M Smucker") for company in companies]
companies = [company.replace("Zions Bancorporation","Zions Bancorporation,") for company in companies]
companies = [company.replace("Alaska Air Group","Alaska Air") for company in companies]

# %%
companies = [company.replace(".com","") for company in companies]
companies = [company.replace(" & Co.","") for company in companies]
companies = [company.replace(" Co.","") for company in companies]
companies = [company.replace(" Corp.","") for company in companies]
companies = [company.replace(" Inc.","") for company in companies]
companies = [company.replace(" Incorporated","") for company in companies]
companies = [company.replace(" Inc","") for company in companies]
companies = [company.replace(" Ltd.","") for company in companies]
companies = [company.replace(".","") for company in companies]
companies = [company.replace(" Corporation","") for company in companies]
companies = [company.replace(" Corp","") for company in companies]
companies = [company.replace(" and Company","") for company in companies]
companies = [company.replace(" & Company","") for company in companies]
companies = [company.replace(" Company","") for company in companies]
companies = [company.replace(" Companies","") for company in companies]
companies = [company.replace(" Class A","") for company in companies]
companies = [company.replace(" Class B","") for company in companies]
companies = [company.replace(" Class C","") for company in companies]
companies = [company.replace(" Class P","") for company in companies]
companies = [company.replace(" Plc","") for company in companies]
companies = [company.replace(" plc","") for company in companies]
companies = [company.replace(" PLC","") for company in companies]
companies = [company.replace(" International","") for company in companies]
companies = [company.replace(" Communications","") for company in companies]
companies = [company.replace(" Wholesale","") for company in companies]
companies = [company.replace(" NV","") for company in companies]
companies = [company.replace(" Limited","") for company in companies]
companies = [company.replace("L3Harris Technologies","L3Harris Technologies Inc") for company in companies]
companies = [company.replace("Merck &","Merck") for company in companies]
companies
# Out:
# ['Apple',
#  'Microsoft',
#  'Amazon',
#  'Tesla',
#  'Facebook',
#  'Alphabet',
#  'Berkshire Hathaway',
#  'Johnson & Johnson',
#  'JPMorgan Chase',
#  'Visa',
#  'NVIDIA',
#  'Procter & Gamble',
#  'UnitedHealth Group',
#  'Walt Disney',
#  'Home Depot',
#  'PayPal Holdings',
#  'Mastercard',
#  'Netflix',
#  'Intel',
#  'Comcast',
#  'Bank of America',
#  'Adobe',
#  'Verizon',
#  'Abbott Laboratories',
#  'salesforce inc',
#  'Thermo Fisher Scientific',
#  'AT&T',
#  'Pfizer',
#  'Merck',
#  'Walmart',
#  'Cisco Systems',
#  'Exxon Mobil',
#  'PepsiCo',
#  'Broadcom',
#  'Coca-Cola',
#  'Qualcomm',
#  'AbbVie',
#  'NIKE',
#  'Chevron',
#  'Eli Lilly',
#  'NextEra Energy',
#  'Texas Instruments',
#  'Accenture',
#  "McDonald's",
#  'Costco',
#  'Danaher',
#  'Medtronic',
#  'Bristol-Myers Squibb',
#  'Amgen',
#  'Honeywell',
#  'Union Pacific',
#  'Linde',
#  'Wells Fargo',
#  'Philip Morris',
#  'Citigroup',
#  "Lowe's",
#  'Oracle',
#  'Starbucks',
#  'UPS',
#  'ServiceNow',
#  'IBM',
#  'AMD',
#  'American Tower',
#  'Boeing',
#  'Raytheon Technologies',
#  'BlackRock',
#  '3M',
#  'Caterpillar',
#  'Intuit',
#  'Morgan Stanley',
#  'Goldman Sachs',
#  'General Electric',
#  'CVS Health',
#  'Applied Materials',
#  'Target',
#  'Deere',
#  'Micron Technology',
#  'Intuitive Surgical',
#  'Charter',
#  'Gilead Sciences',
#  'Booking Holdings',
#  'Fidelity National Information Services',
#  'Lockheed Martin',
#  'Charles Schwab',
#  'Mondelez',
#  'Cigna',
#  'Prologis',
#  'S&P Global',
#  'TJX',
#  'American Express',
#  'Becton Dickinson',
#  'Altria',
#  'T-Mobile US',
#  'Stryker',
#  'Zoetis',
#  'Anthem',
#  'Lam Research',
#  'ADP',
#  'Crown Castle',
#  'Activision Blizzard',
#  'Duke Energy',
#  'Equinix',
#  'Colgate-Palmolive',
#  'CME Group',
#  'Chubb',
#  'CSX',
#  'Truist Financial',
#  'General Motors',
#  'Illumina',
#  'Intercontinental Exchange',
#  'Autodesk',
#  'Southern',
#  'PNC Financial Services Group',
#  'Fiserv',
#  'Norfolk Southern',
#  'Vertex Pharmaceuticals',
#  'Air Products and Chemicals',
#  'Dominion Energy',
#  'US Bancorp',
#  'FedEx',
#  'Sherwin-Williams',
#  'Illinois Tool Works',
#  'Analog Devices',
#  'Marsh & McLennan',
#  'ConocoPhillips',
#  'Estee Lauder',
#  'Global Payments',
#  'DuPont de Nemours',
#  'Regeneron Pharmaceuticals',
#  'Ecolab',
#  'Boston Scientific',
#  'Edwards Lifesciences',
#  'Progressive',
#  'Humana',
#  'Eaton',
#  'Emerson Electric',
#  'Newmont',
#  'Aon',
#  'Dollar General',
#  'Capital One Financial',
#  'Northrop Grumman',
#  'Kimberly-Clark',
#  'KLA',
#  'HCA Healthcare',
#  "Moody's",
#  'Waste Management',
#  'Biogen',
#  'Ford Motor',
#  'Electronic Arts',
#  'Chipotle Mexican Grill',
#  'Cognizant Technology Solutions',
#  'IDEXX Laboratories',
#  'Twitter',
#  'Digital Realty Trust',
#  'TE Connectivity',
#  'Exelon',
#  'Roper Technologies',
#  'Freeport-McMoRan',
#  'American Electric Power',
#  'Synopsys',
#  'Ross Stores',
#  'Dow',
#  'Baxter',
#  'Align Technology',
#  'eBay',
#  'Amphenol',
#  'Cadence Design Systems',
#  'Aptiv',
#  'MetLife',
#  'Microchip Technology',
#  'Agilent Technologies',
#  'Johnson Controls',
#  'DexCom',
#  'Constellation Brands',
#  'L3Harris Technologies Inc',
#  'Sysco',
#  'Sempra Energy',
#  'Public Storage',
#  'T Rowe Price Group',
#  'General Mills',
#  'Walgreens Boots Alliance',
#  'Travelers',
#  'IQVIA Holdings',
#  'Parker-Hannifin',
#  'Centene',
#  'MSCI',
#  'Cummins',
#  'General Dynamics',
#  'Trane Technologies',
#  'Alexion Pharmaceuticals',
#  'HP',
#  'Xcel Energy',
#  'Xilinx',
#  'Allstate',
#  'Bank of New York Mellon',
#  'IHS Markit',
#  'PPG Industries',
#  'Monster Beverage',
#  'American Group',
#  'Zimmer Biomet Holdings',
#  "O'Reilly Automotive",
#  'ANSYS',
#  'PACCAR',
#  'Carrier Global',
#  'Marriott',
#  'Prudential Financial',
#  'Yum! Brands',
#  'TransDigm Group',
#  'SBA',
#  'Skyworks Solutions',
#  'Schlumberger',
#  'Simon Property',
#  'Corteva',
#  'Verisk Analytics',
#  'Eversource Energy',
#  'EOG Resources',
#  'Aflac',
#  'Motorola Solutions',
#  'ViacomCBS',
#  'Phillips 66',
#  'ResMed',
#  'American Water Works',
#  'Ball',
#  'Public Service Enterprise Group',
#  'McKesson',
#  'Rockwell Automation',
#  'Cintas',
#  'Paychex',
#  'Hilton Worldwide Holdings',
#  'Marathon Petroleum',
#  'Mettler-Toledo',
#  'Archer-Daniels-Midland',
#  'WEC Energy',
#  'Stanley Black & Decker',
#  'Corning',
#  'Kinder Morgan',
#  'AutoZone',
#  'Willis Towers Watson Public',
#  'Fastenal',
#  'Clorox',
#  'Keysight Technologies',
#  'Southwest Airlines',
#  'AMETEK',
#  'Otis Worldwide',
#  'Kroger',
#  'Welltower',
#  'Williams',
#  'DR Horton',
#  'First Republic Bank',
#  'Etsy',
#  'Discover Financial Services',
#  'VF',
#  'Best Buy',
#  'State Street',
#  'Cerner',
#  'Pioneer Natural Resources',
#  'Maxim Integrated Products',
#  'Consolidated Edison',
#  'Delta Air Lines',
#  'Weyerhaeuser',
#  'Dollar Tree',
#  'Ameriprise Financial',
#  'SVB Financial Group',
#  'Enphase Energy',
#  'Lennar',
#  'DTE Energy',
#  'Take-Two Interactive Software',
#  'AvalonBay Communities',
#  'Copart',
#  'Valero Energy',
#  'Laboratory of America Holdings',
#  'Fortive',
#  'LyondellBasell Industries',
#  'McCormick',
#  'Arthur J Gallagher',
#  'West Pharmaceutical Services',
#  'Edison',
#  'Equifax',
#  'MarketAxess Holdings',
#  'Kraft Heinz',
#  'PPL',
#  'Hershey',
#  'CBRE',
#  'Equity Residential',
#  'Hologic',
#  'Zebra Technologies',
#  'Realtyome',
#  'Viatris',
#  'Fifth Third Bancorp',
#  'Qorvo',
#  'Church & Dwight',
#  'FLEETCOR Technologies',
#  'Alexandria Real Estate Equities',
#  'Vulcan Materials',
#  'Fortinet',
#  'VeriSign',
#  'CDW',
#  'International Paper',
#  'Teradyne',
#  'Paycom Software',
#  'Catalent',
#  'Kansas City Southern',
#  'CarMax',
#  'Old Dominion Freight Line',
#  'Republic Services',
#  'Entergy',
#  'Tyson Foods',
#  'Northern Trust',
#  'Synchrony Financial',
#  'Martin Marietta Materials',
#  'United Rentals',
#  'Akamai Technologies',
#  'Ameren',
#  'Quest Diagnostics',
#  'Cooper',
#  'Ventas',
#  'ONEOK',
#  'Albemarle',
#  'Teleflex',
#  'Xylem',
#  'Western Digital',
#  'Garmin',
#  'Hartford Financial Services Group',
#  'Expedia Group',
#  'Arista Networks',
#  'Tyler Technologies',
#  'Occidental Petroleum',
#  'Amcor',
#  'Trimble',
#  'M&T Bank',
#  'PerkinElmer',
#  'Dover',
#  'Incyte',
#  'FirstEnergy',
#  'Broadridge Financial Solutions',
#  'KeyCorp',
#  'Conagra Brands',
#  'WW Grainger',
#  'Waters',
#  'Regions Financial',
#  'AES',
#  'CMS Energy',
#  'Healthpeak Properties',
#  'Citrix Systems',
#  'Tractor Supply',
#  'Las Vegas Sands',
#  'Cardinal Health',
#  'Hewlett Packard Enterprise',
#  'Nasdaq',
#  'STERIS',
#  'Ulta Beauty',
#  'Citizens Financial',
#  'NVR',
#  'Ingersoll Rand',
#  'Essex Property Trust',
#  'Halliburton',
#  'AmerisourceBergen',
#  'Darden Restaurants',
#  'ABIOMED',
#  'Mid-America Apartment Communities',
#  'Expeditors of Washington',
#  'Duke Realty',
#  'Extra Space Storage',
#  'Kellogg',
#  'Seagate Technology',
#  'Hess',
#  'Nucor',
#  'NetApp',
#  "Domino's Pizza",
#  'Pool',
#  'Masco',
#  'Celanese',
#  'IDEX',
#  'FMC',
#  'Leidos Holdings',
#  'Carnival',
#  'Teledyne Technologies',
#  'Gartner',
#  'Genuine Parts',
#  'Baker Hughes',
#  'Westinghouse Air Brake Technologies',
#  'Eastman Chemical',
#  'Omnicom Group',
#  'Huntington Bancshares',
#  'Jacobs Engineering Group',
#  'Hormel Foods',
#  'Brown-Forman',
#  'J M Smucker',
#  'Cincinnati Financial',
#  'Principal Financial Group',
#  'Boston Properties',
#  'Avery Dennison',
#  'Packaging of America',
#  'Bio-Rad Laboratories',
#  'NortonLifeLock',
#  'Raymond James Financial',
#  'Fortune Brands Home & Security',
#  'Alliant Energy',
#  'Evergy',
#  'Royal Caribbean Group',
#  'F5 Networks',
#  'Hasbro',
#  'PulteGroup',
#  'MGM Resorts',
#  'DENTSPLY SIRONA',
#  'CH Robinson Worldwide',
#  'United Airlines Holdings',
#  'Whirlpool',
#  'Lumen Technologies',
#  'CenterPoint Energy',
#  'JB Hunt Transport Services',
#  'UDR',
#  'Jack Henry & Associates',
#  'Atmos Energy',
#  'Lamb Weston Holdings',
#  'WestRock',
#  'Fox',
#  'Loews',
#  'Textron',
#  'NRG Energy',
#  'BorgWarner',
#  'American Airlines Group',
#  'Cboe Global Markets',
#  'Advance Auto Parts',
#  'Allegion',
#  'Quanta Services',
#  'LKQ',
#  'Snap-on',
#  'Universal Health Services',
#  'Devon Energy',
#  'Wynn Resorts',
#  'L Brands',
#  'Howmet Aerospace',
#  'Campbell Soup',
#  'Interpublic Group of',
#  'Live Nation Entertainment',
#  'Iron Mountain',
#  'Henry Schein',
#  'Host Hotels & Resorts',
#  'Molson Coors Beverage',
#  'Western Union',
#  'Mosaic',
#  'Newell Brands',
#  'CF Industries Holdings',
#  'Diamondback Energy',
#  'Pentair',
#  'W R Berkley',
#  'Tapestry',
#  'Globe Life',
#  'DaVita',
#  'Mohawk Industries',
#  'Pinnacle West Capital',
#  'NiSource',
#  'Everest Re Group',
#  'Lincoln National',
#  'IPG Photonics',
#  'Juniper Networks',
#  'Nielsen Holdings',
#  'Comerica',
#  'Invesco',
#  'Rollins',
#  'Assurant',
#  'Robert Half',
#  'A O Smith',
#  'News',
#  'Cabot Oil & Gas',
#  'Regency Centers',
#  'Zions Bancorporation, NA',
#  'DISH Network',
#  'Franklin Resources',
#  'Kimco Realty',
#  'Norwegian Cruise Line Holdings',
#  'FLIR Systems',
#  'Discovery',
#  'Sealed Air',
#  'DXC Technology',
#  'Huntington Ingalls Industries',
#  'Alaska Air',
#  'Vornado Realty Trust',
#  'Federal Realty Investment Trust',
#  'Perrigo',
#  'PVH',
#  "People's United Financial",
#  'Marathon Oil',
#  'Apache',
#  'Leggett & Platt',
#  'Hanesbrands',
#  'Ralph Lauren',
#  'NOV',
#  'Unum Group',
#  'SL Green Realty',
#  'Flowserve',
#  'TechnipFMC',
#  'Vontier',
#  'HollyFrontier',
#  'Gap',
#  'Xerox Holdings',
#  'Under Armour']

# %%
companies = [company.lower() for company in companies]
companies = [company.replace("&","-") for company in companies]
companies = [company.replace(" ","-") for company in companies]
companies = [company.replace("---","-") for company in companies]
companies = [company.replace("--","-") for company in companies]
companies
# Out:
# ['apple',
#  'microsoft',
#  'amazon',
#  'tesla',
#  'facebook',
#  'alphabet',
#  'berkshire-hathaway',
#  'johnson-johnson',
#  'jpmorgan-chase',
#  'visa',
#  'nvidia',
#  'procter-gamble',
#  'unitedhealth-group',
#  'walt-disney',
#  'home-depot',
#  'paypal-holdings',
#  'mastercard',
#  'netflix',
#  'intel',
#  'comcast',
#  'bank-of-america',
#  'adobe',
#  'verizon',
#  'abbott-laboratories',
#  'salesforce-inc',
#  'thermo-fisher-scientific',
#  'at-t',
#  'pfizer',
#  'merck',
#  'walmart',
#  'cisco-systems',
#  'exxon-mobil',
#  'pepsico',
#  'broadcom',
#  'coca-cola',
#  'qualcomm',
#  'abbvie',
#  'nike',
#  'chevron',
#  'eli-lilly',
#  'nextera-energy',
#  'texas-instruments',
#  'accenture',
#  "mcdonald's",
#  'costco',
#  'danaher',
#  'medtronic',
#  'bristol-myers-squibb',
#  'amgen',
#  'honeywell',
#  'union-pacific',
#  'linde',
#  'wells-fargo',
#  'philip-morris',
#  'citigroup',
#  "lowe's",
#  'oracle',
#  'starbucks',
#  'ups',
#  'servicenow',
#  'ibm',
#  'amd',
#  'american-tower',
#  'boeing',
#  'raytheon-technologies',
#  'blackrock',
#  '3m',
#  'caterpillar',
#  'intuit',
#  'morgan-stanley',
#  'goldman-sachs',
#  'general-electric',
#  'cvs-health',
#  'applied-materials',
#  'target',
#  'deere',
#  'micron-technology',
#  'intuitive-surgical',
#  'charter',
#  'gilead-sciences',
#  'booking-holdings',
#  'fidelity-national-information-services',
#  'lockheed-martin',
#  'charles-schwab',
#  'mondelez',
#  'cigna',
#  'prologis',
#  's-p-global',
#  'tjx',
#  'american-express',
#  'becton-dickinson',
#  'altria',
#  't-mobile-us',
#  'stryker',
#  'zoetis',
#  'anthem',
#  'lam-research',
#  'adp',
#  'crown-castle',
#  'activision-blizzard',
#  'duke-energy',
#  'equinix',
#  'colgate-palmolive',
#  'cme-group',
#  'chubb',
#  'csx',
#  'truist-financial',
#  'general-motors',
#  'illumina',
#  'intercontinental-exchange',
#  'autodesk',
#  'southern',
#  'pnc-financial-services-group',
#  'fiserv',
#  'norfolk-southern',
#  'vertex-pharmaceuticals',
#  'air-products-and-chemicals',
#  'dominion-energy',
#  'us-bancorp',
#  'fedex',
#  'sherwin-williams',
#  'illinois-tool-works',
#  'analog-devices',
#  'marsh-mclennan',
#  'conocophillips',
#  'estee-lauder',
#  'global-payments',
#  'dupont-de-nemours',
#  'regeneron-pharmaceuticals',
#  'ecolab',
#  'boston-scientific',
#  'edwards-lifesciences',
#  'progressive',
#  'humana',
#  'eaton',
#  'emerson-electric',
#  'newmont',
#  'aon',
#  'dollar-general',
#  'capital-one-financial',
#  'northrop-grumman',
#  'kimberly-clark',
#  'kla',
#  'hca-healthcare',
#  "moody's",
#  'waste-management',
#  'biogen',
#  'ford-motor',
#  'electronic-arts',
#  'chipotle-mexican-grill',
#  'cognizant-technology-solutions',
#  'idexx-laboratories',
#  'twitter',
#  'digital-realty-trust',
#  'te-connectivity',
#  'exelon',
#  'roper-technologies',
#  'freeport-mcmoran',
#  'american-electric-power',
#  'synopsys',
#  'ross-stores',
#  'dow',
#  'baxter',
#  'align-technology',
#  'ebay',
#  'amphenol',
#  'cadence-design-systems',
#  'aptiv',
#  'metlife',
#  'microchip-technology',
#  'agilent-technologies',
#  'johnson-controls',
#  'dexcom',
#  'constellation-brands',
#  'l3harris-technologies-inc',
#  'sysco',
#  'sempra-energy',
#  'public-storage',
#  't-rowe-price-group',
#  'general-mills',
#  'walgreens-boots-alliance',
#  'travelers',
#  'iqvia-holdings',
#  'parker-hannifin',
#  'centene',
#  'msci',
#  'cummins',
#  'general-dynamics',
#  'trane-technologies',
#  'alexion-pharmaceuticals',
#  'hp',
#  'xcel-energy',
#  'xilinx',
#  'allstate',
#  'bank-of-new-york-mellon',
#  'ihs-markit',
#  'ppg-industries',
#  'monster-beverage',
#  'american-group',
#  'zimmer-biomet-holdings',
#  "o'reilly-automotive",
#  'ansys',
#  'paccar',
#  'carrier-global',
#  'marriott',
#  'prudential-financial',
#  'yum!-brands',
#  'transdigm-group',
#  'sba',
#  'skyworks-solutions',
#  'schlumberger',
#  'simon-property',
#  'corteva',
#  'verisk-analytics',
#  'eversource-energy',
#  'eog-resources',
#  'aflac',
#  'motorola-solutions',
#  'viacomcbs',
#  'phillips-66',
#  'resmed',
#  'american-water-works',
#  'ball',
#  'public-service-enterprise-group',
#  'mckesson',
#  'rockwell-automation',
#  'cintas',
#  'paychex',
#  'hilton-worldwide-holdings',
#  'marathon-petroleum',
#  'mettler-toledo',
#  'archer-daniels-midland',
#  'wec-energy',
#  'stanley-black-decker',
#  'corning',
#  'kinder-morgan',
#  'autozone',
#  'willis-towers-watson-public',
#  'fastenal',
#  'clorox',
#  'keysight-technologies',
#  'southwest-airlines',
#  'ametek',
#  'otis-worldwide',
#  'kroger',
#  'welltower',
#  'williams',
#  'dr-horton',
#  'first-republic-bank',
#  'etsy',
#  'discover-financial-services',
#  'vf',
#  'best-buy',
#  'state-street',
#  'cerner',
#  'pioneer-natural-resources',
#  'maxim-integrated-products',
#  'consolidated-edison',
#  'delta-air-lines',
#  'weyerhaeuser',
#  'dollar-tree',
#  'ameriprise-financial',
#  'svb-financial-group',
#  'enphase-energy',
#  'lennar',
#  'dte-energy',
#  'take-two-interactive-software',
#  'avalonbay-communities',
#  'copart',
#  'valero-energy',
#  'laboratory-of-america-holdings',
#  'fortive',
#  'lyondellbasell-industries',
#  'mccormick',
#  'arthur-j-gallagher',
#  'west-pharmaceutical-services',
#  'edison',
#  'equifax',
#  'marketaxess-holdings',
#  'kraft-heinz',
#  'ppl',
#  'hershey',
#  'cbre',
#  'equity-residential',
#  'hologic',
#  'zebra-technologies',
#  'realtyome',
#  'viatris',
#  'fifth-third-bancorp',
#  'qorvo',
#  'church-dwight',
#  'fleetcor-technologies',
#  'alexandria-real-estate-equities',
#  'vulcan-materials',
#  'fortinet',
#  'verisign',
#  'cdw',
#  'international-paper',
#  'teradyne',
#  'paycom-software',
#  'catalent',
#  'kansas-city-southern',
#  'carmax',
#  'old-dominion-freight-line',
#  'republic-services',
#  'entergy',
#  'tyson-foods',
#  'northern-trust',
#  'synchrony-financial',
#  'martin-marietta-materials',
#  'united-rentals',
#  'akamai-technologies',
#  'ameren',
#  'quest-diagnostics',
#  'cooper',
#  'ventas',
#  'oneok',
#  'albemarle',
#  'teleflex',
#  'xylem',
#  'western-digital',
#  'garmin',
#  'hartford-financial-services-group',
#  'expedia-group',
#  'arista-networks',
#  'tyler-technologies',
#  'occidental-petroleum',
#  'amcor',
#  'trimble',
#  'm-t-bank',
#  'perkinelmer',
#  'dover',
#  'incyte',
#  'firstenergy',
#  'broadridge-financial-solutions',
#  'keycorp',
#  'conagra-brands',
#  'ww-grainger',
#  'waters',
#  'regions-financial',
#  'aes',
#  'cms-energy',
#  'healthpeak-properties',
#  'citrix-systems',
#  'tractor-supply',
#  'las-vegas-sands',
#  'cardinal-health',
#  'hewlett-packard-enterprise',
#  'nasdaq',
#  'steris',
#  'ulta-beauty',
#  'citizens-financial',
#  'nvr',
#  'ingersoll-rand',
#  'essex-property-trust',
#  'halliburton',
#  'amerisourcebergen',
#  'darden-restaurants',
#  'abiomed',
#  'mid-america-apartment-communities',
#  'expeditors-of-washington',
#  'duke-realty',
#  'extra-space-storage',
#  'kellogg',
#  'seagate-technology',
#  'hess',
#  'nucor',
#  'netapp',
#  "domino's-pizza",
#  'pool',
#  'masco',
#  'celanese',
#  'idex',
#  'fmc',
#  'leidos-holdings',
#  'carnival',
#  'teledyne-technologies',
#  'gartner',
#  'genuine-parts',
#  'baker-hughes',
#  'westinghouse-air-brake-technologies',
#  'eastman-chemical',
#  'omnicom-group',
#  'huntington-bancshares',
#  'jacobs-engineering-group',
#  'hormel-foods',
#  'brown-forman',
#  'j-m-smucker',
#  'cincinnati-financial',
#  'principal-financial-group',
#  'boston-properties',
#  'avery-dennison',
#  'packaging-of-america',
#  'bio-rad-laboratories',
#  'nortonlifelock',
#  'raymond-james-financial',
#  'fortune-brands-home-security',
#  'alliant-energy',
#  'evergy',
#  'royal-caribbean-group',
#  'f5-networks',
#  'hasbro',
#  'pultegroup',
#  'mgm-resorts',
#  'dentsply-sirona',
#  'ch-robinson-worldwide',
#  'united-airlines-holdings',
#  'whirlpool',
#  'lumen-technologies',
#  'centerpoint-energy',
#  'jb-hunt-transport-services',
#  'udr',
#  'jack-henry-associates',
#  'atmos-energy',
#  'lamb-weston-holdings',
#  'westrock',
#  'fox',
#  'loews',
#  'textron',
#  'nrg-energy',
#  'borgwarner',
#  'american-airlines-group',
#  'cboe-global-markets',
#  'advance-auto-parts',
#  'allegion',
#  'quanta-services',
#  'lkq',
#  'snap-on',
#  'universal-health-services',
#  'devon-energy',
#  'wynn-resorts',
#  'l-brands',
#  'howmet-aerospace',
#  'campbell-soup',
#  'interpublic-group-of',
#  'live-nation-entertainment',
#  'iron-mountain',
#  'henry-schein',
#  'host-hotels-resorts',
#  'molson-coors-beverage',
#  'western-union',
#  'mosaic',
#  'newell-brands',
#  'cf-industries-holdings',
#  'diamondback-energy',
#  'pentair',
#  'w-r-berkley',
#  'tapestry',
#  'globe-life',
#  'davita',
#  'mohawk-industries',
#  'pinnacle-west-capital',
#  'nisource',
#  'everest-re-group',
#  'lincoln-national',
#  'ipg-photonics',
#  'juniper-networks',
#  'nielsen-holdings',
#  'comerica',
#  'invesco',
#  'rollins',
#  'assurant',
#  'robert-half',
#  'a-o-smith',
#  'news',
#  'cabot-oil-gas',
#  'regency-centers',
#  'zions-bancorporation,-na',
#  'dish-network',
#  'franklin-resources',
#  'kimco-realty',
#  'norwegian-cruise-line-holdings',
#  'flir-systems',
#  'discovery',
#  'sealed-air',
#  'dxc-technology',
#  'huntington-ingalls-industries',
#  'alaska-air',
#  'vornado-realty-trust',
#  'federal-realty-investment-trust',
#  'perrigo',
#  'pvh',
#  "people's-united-financial",
#  'marathon-oil',
#  'apache',
#  'leggett-platt',
#  'hanesbrands',
#  'ralph-lauren',
#  'nov',
#  'unum-group',
#  'sl-green-realty',
#  'flowserve',
#  'technipfmc',
#  'vontier',
#  'hollyfrontier',
#  'gap',
#  'xerox-holdings',
#  'under-armour']

# %% [markdown]
# Собираем остальные данные из таблицы и создаем новую, в которую переносим уже измененные данные

# %%
tickers = splist.Ticker.tolist()
sectors = splist.Sector.tolist()
subsectors = splist['Sub-sector'].tolist()

# %%
new_data = pd.DataFrame(zip(companies, tickers, sectors, subsectors), columns=['Company','Ticker', 'Sector', 'Sub-sector'])
new_data
# Out:
#             Company Ticker                  Sector  \
# 0             apple   AAPL  Information Technology
# 1         microsoft   MSFT  Information Technology
# 2            amazon   AMZN  Consumer Discretionary
# 3             tesla   TSLA  Consumer Discretionary
# 4          facebook     FB  Communication Services
# ..              ...    ...                     ...
# 493         vontier    VNT  Information Technology
# 494   hollyfrontier    HFC                  Energy
# 495             gap    GPS  Consumer Discretionary
# 496  xerox-holdings    XRX  Information Technology
# 497    under-armour    UAA  Consumer Discretionary
#
#                                      Sub-sector
# 0    Technology Hardware, Storage & Peripherals
# 1                              Systems Software
# 2            Internet & Direct Marketing Retail
# 3                      Automobile Manufacturers
# 4                  Interactive Media & Services
# ..                                          ...
# 493          Electronic Equipment & Instruments
# 494              Oil & Gas Refining & Marketing
# 495                              Apparel Retail
# 496  Technology Hardware, Storage & Peripherals
# 497         Apparel, Accessories & Luxury Goods
#
# [498 rows x 4 columns]

# %% [markdown]
# Проверяем на наличие повторов среди компаний

# %%
new_data.Company.value_counts()
# Out:
# invesco                       1
# w-r-berkley                   1
# aptiv                         1
# devon-energy                  1
# intercontinental-exchange     1
#                              ..
# sysco                         1
# phillips-66                   1
# westrock                      1
# clorox                        1
# hewlett-packard-enterprise    1
# Name: Company, Length: 498, dtype: int64

# %% [markdown]
# все отлично, загружаем таблицу в новый файл

# %%
new_data.to_csv(r"Data/splist_for_parser.csv", index = False)
